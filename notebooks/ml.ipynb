# %%
import re
import pandas as pd
import numpy as np

import folium as fl
import seaborn as sns

import geopandas as gpd
import matplotlib.pyplot as plt


from property_anomaly_detector.ml.detect_anomalies import detect

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

pd.set_option('display.max_rows', 700)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Top 200 Outliers

# %%
anomalies = detect(n_neighbors=2, contamination=0.02)

re = anomalies[['district', 'postcode', 'property_type', 'furnished_state', 'shared_occupancy', 'num_bedrooms', 'num_bathrooms', 'latitude', 'longitude', 'monthly_rental_price', 'decision_scores']].sort_values(by='decision_scores', ascending=False)
re[:200]
# Out:
# Index(['num_floors', 'num_bedrooms', 'latitude', 'furnished_state', 'category',
#        'property_type', 'longitude', 'details_url', 'district', 'num_recepts',
#        'num_bathrooms', 'monthly_rental_price', 'shared_occupancy', 'postcode',
#        'area_name'],
#       dtype='object')
# Index(['latitude', 'longitude', 'monthly_rental_price', 'shared_occupancy'], dtype='object')
#       district postcode        property_type           furnished_state  \
# 32544     SE16       SE                                           None
# 47234       E8        E               Studio                      None
# 1180       IG3       IG               Studio                 furnished
# 49162      E16        E       Terraced house               unfurnished
# 45045      BR3       BR                 Flat                 furnished
# 68083      SM2       SM               Studio               unfurnished
# 6322      NW10       NW       Detached house            part_furnished
# ...
